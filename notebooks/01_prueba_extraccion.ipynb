# %% [markdown]
# # Pruebas

# %%
import os
import sys

# 1. Configuración de la ruta:
# Como el notebook está dentro de la carpeta 'notebooks/', 
# necesitamos decirle a Python que busque módulos en la carpeta padre (la raíz del proyecto)
sys.path.append(os.path.abspath('..'))

# 2. Importar tu función desde el módulo que creaste
from src.ingesta.excel_parser import extraer_tablas_excel_a_md

# 3. Definir las rutas (relativas a la raíz del proyecto)
ruta_entrada = "../data/01_raw/catalogos_ml.xlsx"
ruta_salida = "../data/02_interim/catalogos_ml.md"

# 4. Ejecutar la prueba
print("Iniciando prueba de extracción...")
extraer_tablas_excel_a_md(ruta_excel=ruta_entrada, ruta_salida_md=ruta_salida)
# Out:
# Iniciando prueba de extracción...
# ✅ Éxito: 6 pestañas convertidas. Guardado en '../data/02_interim/catalogos_ml.md'
